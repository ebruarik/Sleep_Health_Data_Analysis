# %% [markdown]
# Uyku Sağlığı ve Yaşam Tarzı Analizi (Veri Temizleme Projesi)
#
# Bu proje, bireylerin yaşam tarzı alışkanlıklarının uyku kalitesi üzerindeki etkilerini
# incelemek amacıyla hazırlanan veri setinin temizlenmesi ve analize hazır hale getirilmesi sürecini kapsar.
#
# 1: Kütüphanelerin Yüklenmesi ve Verinin Okunması
#
# Analiz sürecinde kullanacağımız temel Python kütüphanelerini yüklüyoruz ve veri setimizi projemize dahil ediyoruz ve inceliyoruz.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('../data/Sleep_health_and_lifestyle_dataset.csv')

df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %% [markdown]
# 2: Eksik Veri Yönetimi
#
# Veri setindeki "Sleep Disorder" sütununda yer alan boş değerleri analiz ediyoruz.
# Bu boşluklar birer hata değil, uyku bozukluğu olmayan bireyleri temsil etmektedir.
# Bu veriler 'None' etiketiyle doldurularak veri seti bütünlüğü sağlanacaktır.

# %%
print("eksik değerler:" , df.isnull().sum())

df['Sleep Disorder'] = df['Sleep Disorder'].fillna('None')

print("doldurma sonrası  eksik değerler:" , df.isnull().sum())
df.head(10)
# Out:
# eksik değerler: Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64
# doldurma sonrası  eksik değerler: Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# ...

# %% [markdown]
# 3: Veri Ayrıştırma
#
# Metin formatında olan 'Blood Pressure' (tansiyon ) verisi matematiksel analize uygun hale getirilmesi için '/'
# karakterinden bölünerek büyük(Systolic_BP) ve küçük(Diastolic_BP) olmak üzere iki ayrı sayısal sütuna dönüştürülecek.

# %%
df[['Systolic_BP' , 'Diastolic_BP']] = df['Blood Pressure'].str.split('/', expand = True).astype(int)

df[['Blood Pressure', 'Systolic_BP' , 'Diastolic_BP']].head()
# Out:
#   Blood Pressure  Systolic_BP  Diastolic_BP
# 0         126/83          126            83
# 1         125/80          125            80
# 2         125/80          125            80
# 3         140/90          140            90
# 4         140/90          140            90

# %% [markdown]
# 4: Keşifçi Veri Analizi (EDA) ve Görselleştirme
#
# Bu aşamada, temizlediğimiz veriler arasındaki ilişkileri görselleştirerek anlamlı içgörüler elde ediyoruz.
# Özellikle meslek grupları, stres seviyeleri ve yeni oluşturduğumuz tansiyon sütunları arasındaki bağlantıları inceleyeceğiz.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Occupation', y='Stress Level', data=df, palette='viridis', errorbar=None)
plt.title('Mesleklere Göre Ortalama Stres Seviyesi')
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
# Satış Temsilcileri (Sales Representatives) en yüksek stres seviyesine (8) sahip meslek grubudur.
# Mühendisler ve Yöneticiler, Doktorlara kıyasla daha düşük stres seviyeleri raporlamıştır.
# Bu yüksek stres seviyesinin, dün ayrıştırdığımız Systolic_BP (Büyük Tansiyon) verilerini yukarı çekip çekmediği
# bir sonraki korelasyon analizimizde incelenecektir.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.regplot(x='Stress Level', y='Systolic_BP', data=df, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Stres Seviyesi ve Büyük Tansiyon (Systolic) İlişkisi')
plt.xlabel('Stres Seviyesi')
plt.ylabel('Büyük Tansiyon')
plt.show()

# %% [markdown]
# Stres ve Büyük Tansiyon (Systolic_BP) arasında yaptığımız regresyon analizinde, iki değişken arasında anlamlı bir korelasyon saptanmamıştır.
# Stres seviyesi artsa bile tansiyon değerleri benzer bir dağılım sergilemektedir.
# Tansiyon üzerinde stresin yanı sıra; 'BMI Category' (Kilo), 'Age' (Yaş) veya 'Physical Activity Level' gibi diğer faktörlerin
# daha baskın bir etkisi olabilir.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='BMI Category', y='Systolic_BP', data=df, palette='Set2')
plt.title('Vücut Kitle Endeksi (BMI) ve Büyük Tansiyon İlişkisi')
plt.show()

# %% [markdown]
# Tansiyonu stres yükseltmiyorsa ne yükseltiyor?
# (BMI (Kilo durumu) ile olan ilişkisine bakıldı çünkü kilonun tansiyonla ilişkisi genellikle çok daha güçlüdür.)
# Yukarıdaki grafikte de görüldüğü üzere stres faktörünün aksine, BMI kategorisinin tansiyon değerleri üzerinde doğrudan ve güçlü bir etkisi olduğu gözlemlenmiştir. Overweight kategorisindeki bireylerin büyük tansiyon ortalaması belirgin şekilde yüksektir.
# Normal kilolu bireylerde tansiyon değerleri daha düşük ve dengeli bir dağılım sergilemektedir.
# Bu bulgu, uyku sağlığı ve tansiyon üzerinde kilo yönetiminin stresten daha öncelikli bir risk faktörü olabileceğini göstermektedir.

# %% [markdown]
# 5: Yaş ve Uyku Kalitesi Analizi
# Projenin final analizinde, yaş değişkeninin uyku kalitesi üzerindeki etkisini inceliyoruz.
# Bu, demografik verilerin sağlık parametreleriyle nasıl birleştiğini görmemizi sağlayacak.

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Age', y='Quality of Sleep', data=df, marker='o', color='purple')
plt.title('Yaşa Göre Uyku Kalitesi Değişimi')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# Yaş ve Uyku Kalitesi İlişkisi Analizi
# Grafiği incelediğimizde, yaş ilerledikçe uyku kalitesinde genel bir yükseliş trendi olduğu gözlemlenmiştir:
#
# Genç Yetişkinlik (27-35 Yaş): Uyku kalitesinin en dalgalı olduğu dönemdir. Bu durum,
# kariyer başlangıcı ve yaşam tarzı değişikliklerine bağlı stresle ilişkilendirilebilir.
# Orta Yaş Geçişi (40-50 Yaş):Uyku kalitesinde geçici bir düşüş görülse de genel seviye 6.0'ın üzerinde kalmaktadır.
# İleri Yaş (50-60 Yaş):Veri setindeki en yüksek ve en stabil uyku kalitesi (9.0 puan) bu grupta saptanmıştır.
#
# Sonuç: Beklentilerin aksine, bu veri grubunda yaşlılık "daha kaliteli uyku" ile pozitif bir korelasyon göstermektedir.

# %% [markdown]
#  Proje Sonuç ve Değerlendirme Raporu
#
# Bu çalışma kapsamında, bireylerin yaşam tarzı faktörlerinin uyku sağlığı ve genel sağlık göstergeleri üzerindeki etkileri
# "Sleep Health and Lifestyle" veri seti (Kaggle'dan hazır alınmıştır) üzerinden derinlemesine analiz edilmiştir.
#
#   Temel Bulgular
#
# 1. Mesleki Stres ve Uyku:
#    - Analizler, Satış Temsilcileri ve Doktorların en yüksek stres seviyelerine sahip olduğunu göstermiştir.
#    - İlginç bir şekilde, Mühendisler daha düşük stres seviyeleriyle daha dengeli bir profil sergilemektedir.
#
# 2. Tansiyonun Gizli Faktörü (BMI):
#    - Başlangıçta stresin tansiyonu (Blood Pressure) doğrudan yükselttiği varsayılsa da, regresyon analizi bu ilişkiyi zayıf bulmuştur.
#    - Asıl korelasyon BMI (Vücut Kitle Endeksi) ile saptanmıştır; Overweight ve Obese kategorisindeki bireylerin tansiyon değerleri,
#      normal kilolulara göre anlamlı derecede yüksektir.
#
# 3. Yaş ve Uyku Kalitesi Paradoksu:
#    - Genel kanının aksine, bu veri setinde *yaş ilerledikçe uyku kalitesinin arttığı
#      ve 50 yaş üstü grubun en stabil uyku puanlarına (9.0) sahip olduğu görülmüştür. Genç yetişkinlik dönemi ise en dalgalı süreci oluşturmaktadır.
#
#   Teknik Kazanımlar
# - pandas ile veri temizliği ve NaN değer yönetimi yapıldı.
# - Blood Pressure gibi karmaşık metin verileri Systolic ve Diastolic olarak ayrıştırılarak sayısal analize hazır hale getirildi (Feature Engineering).
# - seaborn ve matplotlib kütüphaneleriyle verideki gizli trendler görselleştirildi.
#
#   Gelecek Önerileri
# - Uyku kalitesini artırmak için sadece stres yönetimine değil, kilo kontrolüne de odaklanılmalıdır.
# - Mesleki stresin azaltılması için özellikle satış ve sağlık sektöründe kurumsal refah programları uygulanması önerilir.
